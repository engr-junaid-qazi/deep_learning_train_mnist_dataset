# %%
conda install pytorch
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\HP\anaconda3
#
#   added / updated specs:
#     - pytorch
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.12.7          |   py39haa95532_0         149 KB
#     conda-22.11.1              |   py39haa95532_4         892 KB
#     libuv-1.40.0               |       he774522_0         255 KB
#     ninja-1.10.2               |       haa95532_5          14 KB
#     ninja-base-1.10.2          |       h6d14046_5         255 KB
#     pytorch-1.12.1             |cpu_py39h5e1f01c_0        80.6 MB
#     ------------------------------------------------------------
#                                            Total:        82.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   libuv              pkgs/main/win-64::libuv-1.40.0-he774522_0
#   ninja              pkgs/main/win-64::ninja-1.10.2-haa95532_5
#   ninja-base         pkgs/main/win-64::ninja-base-1.10.2-h6d14046_5
#   pytorch            pkgs/main/win-64::pytorch-1.12.1-cpu_py39h5e1f01c_0
#
# The following packages will be UPDATED:
#
#   certifi                          2022.9.24-py39haa95532_0 --> 2022.12.7-py39haa95532_0
#   conda                              22.11.0-py39haa95532_1 --> 22.11.1-py39haa95532_4
#
#
#
# Downloading and Extracting Packages
#
# ninja-1.10.2         | 14 KB     |            |   0%
#
# ninja-base-1.10.2    | 255 KB    |            |   0%
#
#
# pytorch-1.12.1       | 80.6 MB   |            |   0%
#
#
#
# conda-22.11.1        | 892 KB    |            |   0%
#
#
#
#
# certifi-2022.12.7    | 149 KB    |            |   0%
#
#
#
#
#
# libuv-1.40.0         | 255 KB    |            |   0%
#
#
#
# conda-22.11.1        | 892 KB    | 1          |   2%
#
#
#
#
# certifi-2022.12.7    | 149 KB    | #          |  11%
#
#
#
# conda-22.11.1        | 892 KB    | #7         |  18%
# ninja-1.10.2         | 14 KB     | ########## | 100%
#
#
#
#
# certifi-2022.12.7    | 149 KB    | #####3     |  54%
#
#
#
# conda-22.11.1        | 892 KB    | ###9       |  39%
# ninja-1.10.2         | 14 KB     | ########## | 100%
#
#
#
#
# certifi-2022.12.7    | 149 KB    | ########## | 100%
#
#
#
#
# certifi-2022.12.7    | 149 KB    | ########## | 100%
#
#
#
# conda-22.11.1        | 892 KB    | ######4    |  65%
#
#
# pytorch-1.12.1       | 80.6 MB   |            |   0%
#
#
#
#
#
# libuv-1.40.0         | 255 KB    | 6          |   6%
#
#
#
# conda-22.11.1        | 892 KB    | ########9  |  90%
#
#
#
#
#
# libuv-1.40.0         | 255 KB    | ##5        |  25%
#
#
# pytorch-1.12.1       | 80.6 MB   |            |   0%
#
#
#
#
#
# libuv-1.40.0         | 255 KB    | #####6     |  57%
#
#
# pytorch-1.12.1       | 80.6 MB   |            |   0%
#
#
#
# conda-22.11.1        | 892 KB    | ########## | 100%
#
#
#
#
#
# libuv-1.40.0         | 255 KB    | ########## | 100%
#
#
#
#
#
# libuv-1.40.0         | 255 KB    | ########## | 100%
#
#
# pytorch-1.12.1       | 80.6 MB   |            |   0%
#
# ninja-base-1.10.2    | 255 KB    | 6          |   6%
#
#
# pytorch-1.12.1       | 80.6 MB   |            |   1%
#
# ninja-base-1.10.2    | 255 KB    | #8         |  19%
#
#
# pytorch-1.12.1       | 80.6 MB   |            |   1%
#
# ninja-base-1.10.2    | 255 KB    | ######8    |  69%
#
#
# pytorch-1.12.1       | 80.6 MB   |            |   1%
#
#
# pytorch-1.12.1       | 80.6 MB   |            |   1%
#
# ninja-base-1.10.2    | 255 KB    | ########7  |  88%
#
#
# pytorch-1.12.1       | 80.6 MB   | 1          |   1%
#
# ninja-base-1.10.2    | 255 KB    | ########## | 100%
#
#
# pytorch-1.12.1       | 80.6 MB   | 1          |   1%
#
#
# pytorch-1.12.1       | 80.6 MB   | 1          |   1%
#
#
# pytorch-1.12.1       | 80.6 MB   | 1          |   1%
#
#
# pytorch-1.12.1       | 80.6 MB   | 1          |   1%
#
#
# pytorch-1.12.1       | 80.6 MB   | 1          |   1%
#
#
# pytorch-1.12.1       | 80.6 MB   | 1          |   2%
#
#
# pytorch-1.12.1       | 80.6 MB   | 1          |   2%
#
#
# pytorch-1.12.1       | 80.6 MB   | 1          |   2%
#
#
# pytorch-1.12.1       | 80.6 MB   | 1          |   2%
#
#
# pytorch-1.12.1       | 80.6 MB   | 1          |   2%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   2%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   2%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   2%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   2%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   2%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   2%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 2          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 3          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 3          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 3          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 3          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 3          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 3          |   3%
#
#
# pytorch-1.12.1       | 80.6 MB   | 3          |   4%
#
#
# pytorch-1.12.1       | 80.6 MB   | 3          |   4%
#
#
# pytorch-1.12.1       | 80.6 MB   | 3          |   4%
#
#
# pytorch-1.12.1       | 80.6 MB   | 3          |   4%
#
#
# pytorch-1.12.1       | 80.6 MB   | 3          |   4%
#
#
# pytorch-1.12.1       | 80.6 MB   | 4          |   4%
#
#
# pytorch-1.12.1       | 80.6 MB   | 4          |   4%
#
#
# pytorch-1.12.1       | 80.6 MB   | 4          |   5%
#
#
# pytorch-1.12.1       | 80.6 MB   | 4          |   5%
#
#
# pytorch-1.12.1       | 80.6 MB   | 4          |   5%
#
#
# pytorch-1.12.1       | 80.6 MB   | 4          |   5%
#
#
# pytorch-1.12.1       | 80.6 MB   | 4          |   5%
#
#
# pytorch-1.12.1       | 80.6 MB   | 5          |   5%
#
#
# pytorch-1.12.1       | 80.6 MB   | 5          |   5%
#
#
# pytorch-1.12.1       | 80.6 MB   | 5          |   5%
#
#
# pytorch-1.12.1       | 80.6 MB   | 5          |   6%
#
#
# pytorch-1.12.1       | 80.6 MB   | 5          |   6%
#
#
# pytorch-1.12.1       | 80.6 MB   | 5          |   6%
#
#
# pytorch-1.12.1       | 80.6 MB   | 5          |   6%
#
#
# pytorch-1.12.1       | 80.6 MB   | 6          |   6%
#
#
# pytorch-1.12.1       | 80.6 MB   | 6          |   6%
#
#
# pytorch-1.12.1       | 80.6 MB   | 6          |   6%
#
#
# pytorch-1.12.1       | 80.6 MB   | 6          |   6%
#
#
# pytorch-1.12.1       | 80.6 MB   | 6          |   7%
#
#
# pytorch-1.12.1       | 80.6 MB   | 6          |   7%
#
#
# pytorch-1.12.1       | 80.6 MB   | 7          |   7%
#
#
# pytorch-1.12.1       | 80.6 MB   | 7          |   7%
#
#
# pytorch-1.12.1       | 80.6 MB   | 7          |   7%
#
#
# pytorch-1.12.1       | 80.6 MB   | 7          |   7%
#
#
# pytorch-1.12.1       | 80.6 MB   | 7          |   8%
#
#
# pytorch-1.12.1       | 80.6 MB   | 7          |   8%
#
#
# pytorch-1.12.1       | 80.6 MB   | 7          |   8%
#
#
# pytorch-1.12.1       | 80.6 MB   | 7          |   8%
#
#
# pytorch-1.12.1       | 80.6 MB   | 8          |   8%
#
#
# pytorch-1.12.1       | 80.6 MB   | 8          |   8%
#
#
# pytorch-1.12.1       | 80.6 MB   | 8          |   8%
#
#
# pytorch-1.12.1       | 80.6 MB   | 8          |   9%
#
#
# pytorch-1.12.1       | 80.6 MB   | 8          |   9%
#
#
# pytorch-1.12.1       | 80.6 MB   | 8          |   9%
#
#
# pytorch-1.12.1       | 80.6 MB   | 8          |   9%
#
#
# pytorch-1.12.1       | 80.6 MB   | 8          |   9%
#
#
# pytorch-1.12.1       | 80.6 MB   | 9          |   9%
#
#
# pytorch-1.12.1       | 80.6 MB   | 9          |   9%
#
#
# pytorch-1.12.1       | 80.6 MB   | 9          |   9%
#
#
# pytorch-1.12.1       | 80.6 MB   | 9          |   9%
#
#
# pytorch-1.12.1       | 80.6 MB   | 9          |   9%
#
#
# pytorch-1.12.1       | 80.6 MB   | 9          |  10%
#
#
# pytorch-1.12.1       | 80.6 MB   | 9          |  10%
#
#
# pytorch-1.12.1       | 80.6 MB   | 9          |  10%
#
#
# pytorch-1.12.1       | 80.6 MB   | 9          |  10%
#
#
# pytorch-1.12.1       | 80.6 MB   | #          |  10%
#
#
# pytorch-1.12.1       | 80.6 MB   | #          |  10%
#
#
# pytorch-1.12.1       | 80.6 MB   | #          |  10%
#
#
# pytorch-1.12.1       | 80.6 MB   | #          |  10%
#
#
# pytorch-1.12.1       | 80.6 MB   | #          |  10%
#
#
# pytorch-1.12.1       | 80.6 MB   | #          |  11%
#
#
# pytorch-1.12.1       | 80.6 MB   | #          |  11%
#
#
# pytorch-1.12.1       | 80.6 MB   | #          |  11%
#
#
# pytorch-1.12.1       | 80.6 MB   | #          |  11%
#
#
# pytorch-1.12.1       | 80.6 MB   | #          |  11%
#
#
# pytorch-1.12.1       | 80.6 MB   | #          |  11%
#
#
# pytorch-1.12.1       | 80.6 MB   | #1         |  11%
#
#
# pytorch-1.12.1       | 80.6 MB   | #1         |  11%
#
#
# pytorch-1.12.1       | 80.6 MB   | #1         |  11%
#
#
# pytorch-1.12.1       | 80.6 MB   | #1         |  11%
#
#
# pytorch-1.12.1       | 80.6 MB   | #1         |  11%
#
#
# pytorch-1.12.1       | 80.6 MB   | #1         |  12%
#
#
# pytorch-1.12.1       | 80.6 MB   | #1         |  12%
#
#
# pytorch-1.12.1       | 80.6 MB   | #1         |  12%
#
#
# pytorch-1.12.1       | 80.6 MB   | #1         |  12%
#
#
# pytorch-1.12.1       | 80.6 MB   | #1         |  12%
#
#
# pytorch-1.12.1       | 80.6 MB   | #2         |  12%
#
#
# pytorch-1.12.1       | 80.6 MB   | #2         |  12%
#
#
# pytorch-1.12.1       | 80.6 MB   | #2         |  12%
#
#
# pytorch-1.12.1       | 80.6 MB   | #2         |  12%
#
#
# pytorch-1.12.1       | 80.6 MB   | #2         |  12%
#
#
# pytorch-1.12.1       | 80.6 MB   | #2         |  13%
#
#
# pytorch-1.12.1       | 80.6 MB   | #2         |  13%
#
#
# pytorch-1.12.1       | 80.6 MB   | #2         |  13%
#
#
# pytorch-1.12.1       | 80.6 MB   | #2         |  13%
#
#
# pytorch-1.12.1       | 80.6 MB   | #2         |  13%
#
#
# pytorch-1.12.1       | 80.6 MB   | #3         |  13%
#
#
# pytorch-1.12.1       | 80.6 MB   | #3         |  13%
#
#
# pytorch-1.12.1       | 80.6 MB   | #3         |  13%
#
#
# pytorch-1.12.1       | 80.6 MB   | #3         |  13%
#
#
# pytorch-1.12.1       | 80.6 MB   | #3         |  14%
#
#
# pytorch-1.12.1       | 80.6 MB   | #3         |  14%
#
#
# pytorch-1.12.1       | 80.6 MB   | #3         |  14%
#
#
# pytorch-1.12.1       | 80.6 MB   | #4         |  14%
#
#
# pytorch-1.12.1       | 80.6 MB   | #4         |  14%
#
#
# pytorch-1.12.1       | 80.6 MB   | #4         |  14%
#
#
# pytorch-1.12.1       | 80.6 MB   | #4         |  14%
#
#
# pytorch-1.12.1       | 80.6 MB   | #4         |  15%
#
#
# pytorch-1.12.1       | 80.6 MB   | #4         |  15%
#
#
# pytorch-1.12.1       | 80.6 MB   | #4         |  15%
#
#
# pytorch-1.12.1       | 80.6 MB   | #4         |  15%
#
#
# pytorch-1.12.1       | 80.6 MB   | #5         |  15%
#
#
# pytorch-1.12.1       | 80.6 MB   | #5         |  15%
#
#
# pytorch-1.12.1       | 80.6 MB   | #5         |  15%
#
#
# pytorch-1.12.1       | 80.6 MB   | #5         |  15%
#
#
# pytorch-1.12.1       | 80.6 MB   | #5         |  15%
#
#
# pytorch-1.12.1       | 80.6 MB   | #5         |  16%
#
#
# pytorch-1.12.1       | 80.6 MB   | #5         |  16%
#
#
# pytorch-1.12.1       | 80.6 MB   | #5         |  16%
#
#
# pytorch-1.12.1       | 80.6 MB   | #5         |  16%
#
#
# pytorch-1.12.1       | 80.6 MB   | #6         |  16%
#
#
# pytorch-1.12.1       | 80.6 MB   | #6         |  16%
#
#
# pytorch-1.12.1       | 80.6 MB   | #6         |  16%
#
#
# pytorch-1.12.1       | 80.6 MB   | #6         |  16%
#
#
# pytorch-1.12.1       | 80.6 MB   | #6         |  16%
#
#
# pytorch-1.12.1       | 80.6 MB   | #6         |  17%
#
#
# pytorch-1.12.1       | 80.6 MB   | #6         |  17%
#
#
# pytorch-1.12.1       | 80.6 MB   | #6         |  17%
#
#
# pytorch-1.12.1       | 80.6 MB   | #6         |  17%
#
#
# pytorch-1.12.1       | 80.6 MB   | #7         |  17%
#
#
# pytorch-1.12.1       | 80.6 MB   | #7         |  17%
#
#
# pytorch-1.12.1       | 80.6 MB   | #7         |  17%
#
#
# pytorch-1.12.1       | 80.6 MB   | #7         |  17%
#
#
# pytorch-1.12.1       | 80.6 MB   | #7         |  18%
#
#
# pytorch-1.12.1       | 80.6 MB   | #7         |  18%
#
#
# pytorch-1.12.1       | 80.6 MB   | #7         |  18%
#
#
# pytorch-1.12.1       | 80.6 MB   | #7         |  18%
#
#
# pytorch-1.12.1       | 80.6 MB   | #8         |  18%
#
#
# pytorch-1.12.1       | 80.6 MB   | #8         |  18%
#
#
# pytorch-1.12.1       | 80.6 MB   | #8         |  18%
#
#
# pytorch-1.12.1       | 80.6 MB   | #8         |  18%
#
#
# pytorch-1.12.1       | 80.6 MB   | #8         |  18%
#
#
# pytorch-1.12.1       | 80.6 MB   | #8         |  19%
#
#
# pytorch-1.12.1       | 80.6 MB   | #8         |  19%
#
#
# pytorch-1.12.1       | 80.6 MB   | #8         |  19%
#
#
# pytorch-1.12.1       | 80.6 MB   | #8         |  19%
#
#
# pytorch-1.12.1       | 80.6 MB   | #8         |  19%
#
#
# pytorch-1.12.1       | 80.6 MB   | #8         |  19%
#
#
# pytorch-1.12.1       | 80.6 MB   | #9         |  19%
#
#
# pytorch-1.12.1       | 80.6 MB   | #9         |  19%
#
#
# pytorch-1.12.1       | 80.6 MB   | #9         |  19%
#
#
# pytorch-1.12.1       | 80.6 MB   | #9         |  19%
#
#
# pytorch-1.12.1       | 80.6 MB   | #9         |  20%
#
#
# pytorch-1.12.1       | 80.6 MB   | #9         |  20%
#
#
# pytorch-1.12.1       | 80.6 MB   | #9         |  20%
#
#
# pytorch-1.12.1       | 80.6 MB   | #9         |  20%
#
#
# pytorch-1.12.1       | 80.6 MB   | #9         |  20%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##         |  20%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##         |  20%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##         |  20%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##         |  21%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##         |  21%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##         |  21%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##         |  21%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##1        |  21%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##1        |  21%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##1        |  21%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##1        |  21%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##1        |  22%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##1        |  22%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##1        |  22%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##1        |  22%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##2        |  22%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##2        |  22%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##2        |  22%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##2        |  23%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##2        |  23%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##2        |  23%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##3        |  23%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##3        |  23%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##3        |  23%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##3        |  23%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##3        |  24%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##3        |  24%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##3        |  24%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##4        |  24%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##4        |  24%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##4        |  24%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##4        |  25%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##4        |  25%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##4        |  25%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##5        |  25%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##5        |  25%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##5        |  25%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##5        |  25%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##5        |  26%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##5        |  26%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##5        |  26%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##6        |  26%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##6        |  26%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##6        |  26%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##6        |  26%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##6        |  27%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##6        |  27%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##6        |  27%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##6        |  27%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##6        |  27%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##7        |  27%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##7        |  27%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##7        |  27%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##7        |  28%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##7        |  28%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##7        |  28%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##7        |  28%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##7        |  28%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##8        |  28%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##8        |  28%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##8        |  28%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##8        |  28%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##8        |  28%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##8        |  28%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##8        |  29%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##8        |  29%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##8        |  29%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##8        |  29%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##8        |  29%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##9        |  29%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##9        |  29%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##9        |  29%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##9        |  30%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##9        |  30%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##9        |  30%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##9        |  30%
#
#
# pytorch-1.12.1       | 80.6 MB   | ##9        |  30%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###        |  30%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###        |  30%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###        |  30%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###        |  31%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###        |  31%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###        |  31%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###        |  31%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###        |  31%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###1       |  31%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###1       |  31%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###1       |  31%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###1       |  31%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###1       |  32%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###1       |  32%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###1       |  32%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###1       |  32%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###2       |  32%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###2       |  32%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###2       |  32%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###2       |  32%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###2       |  33%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###2       |  33%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###2       |  33%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###3       |  33%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###3       |  33%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###3       |  33%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###3       |  33%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###3       |  33%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###3       |  34%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###3       |  34%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###3       |  34%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###3       |  34%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###4       |  34%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###4       |  34%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###4       |  34%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###4       |  34%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###4       |  35%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###4       |  35%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###4       |  35%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###5       |  35%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###5       |  35%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###5       |  35%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###5       |  35%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###5       |  36%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###5       |  36%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###6       |  36%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###6       |  36%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###6       |  36%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###6       |  36%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###6       |  37%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###6       |  37%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###6       |  37%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###6       |  37%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###6       |  37%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###7       |  37%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###7       |  37%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###7       |  38%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###7       |  38%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###7       |  38%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###7       |  38%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###8       |  38%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###8       |  38%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###8       |  38%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###8       |  38%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###8       |  39%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###8       |  39%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###8       |  39%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###8       |  39%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###9       |  39%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###9       |  39%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###9       |  39%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###9       |  40%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###9       |  40%
#
#
# pytorch-1.12.1       | 80.6 MB   | ###9       |  40%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####       |  40%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####       |  40%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####       |  40%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####       |  40%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####       |  41%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####       |  41%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####       |  41%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####       |  41%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####1      |  41%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####1      |  41%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####1      |  41%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####1      |  41%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####1      |  42%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####1      |  42%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####1      |  42%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####2      |  42%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####2      |  42%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####2      |  42%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####2      |  42%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####2      |  43%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####2      |  43%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####2      |  43%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####2      |  43%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####3      |  43%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####3      |  43%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####3      |  43%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####3      |  43%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####3      |  43%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####3      |  43%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####3      |  44%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####3      |  44%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####3      |  44%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####3      |  44%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####4      |  44%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####4      |  44%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####4      |  44%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####4      |  44%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####4      |  45%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####4      |  45%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####4      |  45%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####4      |  45%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####4      |  45%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####5      |  45%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####5      |  45%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####5      |  45%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####5      |  45%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####5      |  46%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####5      |  46%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####5      |  46%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####5      |  46%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####6      |  46%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####6      |  46%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####6      |  46%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####6      |  46%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####6      |  46%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####6      |  47%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####6      |  47%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####6      |  47%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####6      |  47%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####7      |  47%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####7      |  47%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####7      |  47%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####7      |  47%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####7      |  48%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####7      |  48%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####7      |  48%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####7      |  48%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####7      |  48%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####8      |  48%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####8      |  48%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####8      |  48%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####8      |  48%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####8      |  49%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####8      |  49%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####8      |  49%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####8      |  49%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####8      |  49%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####9      |  49%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####9      |  49%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####9      |  49%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####9      |  49%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####9      |  50%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####9      |  50%
#
#
# pytorch-1.12.1       | 80.6 MB   | ####9      |  50%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####      |  50%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####      |  50%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####      |  50%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####      |  51%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####      |  51%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####      |  51%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####      |  51%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####1     |  51%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####1     |  51%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####1     |  51%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####1     |  51%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####1     |  51%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####1     |  52%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####1     |  52%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####1     |  52%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####2     |  52%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####2     |  52%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####2     |  52%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####2     |  52%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####2     |  53%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####2     |  53%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####2     |  53%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####2     |  53%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####3     |  53%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####3     |  53%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####3     |  53%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####3     |  54%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####3     |  54%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####3     |  54%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####3     |  54%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####4     |  54%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####4     |  54%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####4     |  54%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####4     |  54%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####4     |  55%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####4     |  55%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####4     |  55%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####4     |  55%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####4     |  55%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####5     |  55%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####5     |  55%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####5     |  55%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####5     |  55%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####5     |  55%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####5     |  56%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####5     |  56%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####5     |  56%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####5     |  56%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####5     |  56%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####6     |  56%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####6     |  56%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####6     |  56%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####6     |  56%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####6     |  56%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####6     |  57%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####6     |  57%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####6     |  57%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####6     |  57%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####6     |  57%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####6     |  57%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####7     |  57%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####7     |  57%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####7     |  57%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####7     |  57%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####7     |  57%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####7     |  58%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####7     |  58%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####7     |  58%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####7     |  58%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####8     |  58%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####8     |  58%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####8     |  58%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####8     |  58%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####8     |  59%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####8     |  59%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####8     |  59%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####8     |  59%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####8     |  59%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####9     |  59%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####9     |  59%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####9     |  59%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####9     |  59%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####9     |  59%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####9     |  60%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####9     |  60%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####9     |  60%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####9     |  60%
#
#
# pytorch-1.12.1       | 80.6 MB   | #####9     |  60%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######     |  60%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######     |  60%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######     |  60%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######     |  60%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######     |  61%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######     |  61%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######     |  61%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######     |  61%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######1    |  61%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######1    |  61%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######1    |  61%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######1    |  61%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######1    |  61%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######1    |  62%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######1    |  62%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######1    |  62%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######1    |  62%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######1    |  62%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######2    |  62%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######2    |  62%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######2    |  62%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######2    |  62%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######2    |  63%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######2    |  63%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######2    |  63%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######2    |  63%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######3    |  63%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######3    |  63%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######3    |  63%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######3    |  63%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######3    |  63%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######3    |  64%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######3    |  64%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######3    |  64%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######3    |  64%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######4    |  64%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######4    |  64%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######4    |  64%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######4    |  64%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######4    |  65%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######4    |  65%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######4    |  65%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######4    |  65%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######4    |  65%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######5    |  65%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######5    |  65%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######5    |  65%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######5    |  65%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######5    |  65%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######5    |  65%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######5    |  66%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######5    |  66%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######5    |  66%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######5    |  66%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######6    |  66%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######6    |  66%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######6    |  66%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######6    |  66%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######6    |  66%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######6    |  67%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######6    |  67%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######6    |  67%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######6    |  67%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######7    |  67%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######7    |  67%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######7    |  67%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######7    |  67%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######7    |  68%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######7    |  68%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######7    |  68%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######7    |  68%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######8    |  68%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######8    |  68%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######8    |  68%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######8    |  68%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######8    |  69%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######8    |  69%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######8    |  69%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######8    |  69%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######9    |  69%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######9    |  69%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######9    |  69%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######9    |  70%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######9    |  70%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######9    |  70%
#
#
# pytorch-1.12.1       | 80.6 MB   | ######9    |  70%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######    |  70%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######    |  70%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######    |  70%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######    |  71%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######    |  71%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######    |  71%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######1   |  71%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######1   |  71%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######1   |  71%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######1   |  72%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######1   |  72%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######1   |  72%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######1   |  72%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######2   |  72%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######2   |  72%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######2   |  72%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######2   |  72%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######2   |  72%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######2   |  73%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######2   |  73%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######2   |  73%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######2   |  73%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######3   |  73%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######3   |  73%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######3   |  73%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######3   |  73%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######3   |  73%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######3   |  74%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######3   |  74%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######3   |  74%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######4   |  74%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######4   |  74%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######4   |  74%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######4   |  74%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######4   |  74%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######4   |  75%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######4   |  75%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######4   |  75%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######4   |  75%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######5   |  75%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######5   |  75%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######5   |  75%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######5   |  75%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######5   |  75%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######5   |  76%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######5   |  76%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######5   |  76%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######5   |  76%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######5   |  76%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######5   |  76%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######6   |  76%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######6   |  76%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######6   |  76%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######6   |  76%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######6   |  76%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######6   |  77%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######6   |  77%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######6   |  77%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######6   |  77%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######7   |  77%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######7   |  77%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######7   |  77%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######7   |  77%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######7   |  78%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######7   |  78%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######7   |  78%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######7   |  78%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######7   |  78%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######8   |  78%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######8   |  78%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######8   |  78%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######8   |  78%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######8   |  78%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######8   |  79%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######8   |  79%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######8   |  79%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######8   |  79%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######9   |  79%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######9   |  79%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######9   |  79%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######9   |  79%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######9   |  79%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######9   |  80%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######9   |  80%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######9   |  80%
#
#
# pytorch-1.12.1       | 80.6 MB   | #######9   |  80%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########   |  80%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########   |  80%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########   |  80%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########   |  80%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########   |  81%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########   |  81%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########   |  81%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########   |  81%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########1  |  81%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########1  |  81%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########1  |  81%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########1  |  81%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########1  |  81%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########1  |  82%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########1  |  82%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########1  |  82%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########1  |  82%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########2  |  82%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########2  |  82%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########2  |  82%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########2  |  82%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########2  |  82%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########2  |  82%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########2  |  83%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########2  |  83%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########2  |  83%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########2  |  83%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########2  |  83%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########3  |  83%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########3  |  83%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########3  |  83%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########3  |  83%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########3  |  84%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########3  |  84%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########3  |  84%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########3  |  84%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########3  |  84%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########4  |  84%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########4  |  84%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########4  |  84%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########4  |  84%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########4  |  85%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########4  |  85%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########4  |  85%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########4  |  85%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########5  |  85%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########5  |  85%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########5  |  85%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########5  |  85%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########5  |  86%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########5  |  86%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########5  |  86%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########5  |  86%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########6  |  86%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########6  |  86%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########6  |  86%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########6  |  86%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########6  |  87%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########6  |  87%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########6  |  87%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########6  |  87%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########7  |  87%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########7  |  87%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########7  |  87%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########7  |  87%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########7  |  88%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########7  |  88%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########7  |  88%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########7  |  88%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########7  |  88%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########7  |  88%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########8  |  88%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########8  |  88%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########8  |  88%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########8  |  88%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########8  |  88%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########8  |  89%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########8  |  89%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########8  |  89%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########8  |  89%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########8  |  89%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########9  |  89%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########9  |  89%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########9  |  89%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########9  |  89%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########9  |  89%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########9  |  90%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########9  |  90%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########9  |  90%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########9  |  90%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########9  |  90%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########  |  90%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########  |  90%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########  |  90%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########  |  90%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########  |  91%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########  |  91%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########  |  91%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########  |  91%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########  |  91%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########1 |  91%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########1 |  91%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########1 |  91%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########1 |  91%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########1 |  91%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########1 |  92%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########1 |  92%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########1 |  92%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########1 |  92%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########1 |  92%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########1 |  92%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########2 |  92%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########2 |  92%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########2 |  92%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########2 |  92%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########2 |  93%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########2 |  93%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########2 |  93%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########2 |  93%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########2 |  93%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########2 |  93%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########3 |  93%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########3 |  93%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########3 |  93%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########3 |  93%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########3 |  93%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########3 |  93%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########3 |  94%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########3 |  94%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########3 |  94%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########3 |  94%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########3 |  94%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########4 |  94%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########4 |  94%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########4 |  94%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########4 |  94%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########4 |  94%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########4 |  94%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########4 |  95%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########4 |  95%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########4 |  95%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########4 |  95%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########4 |  95%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########4 |  95%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########5 |  95%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########5 |  95%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########5 |  95%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########5 |  95%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########5 |  95%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########5 |  95%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########5 |  96%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########5 |  96%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########5 |  96%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########5 |  96%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########5 |  96%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########6 |  96%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########6 |  96%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########6 |  96%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########6 |  96%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########6 |  96%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########6 |  97%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########6 |  97%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########6 |  97%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########6 |  97%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########6 |  97%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########6 |  97%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########7 |  97%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########7 |  97%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########7 |  97%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########7 |  97%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########7 |  97%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########7 |  98%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########7 |  98%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########7 |  98%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########7 |  98%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########8 |  98%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########8 |  98%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########8 |  98%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########8 |  99%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########8 |  99%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########8 |  99%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########8 |  99%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########8 |  99%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########9 |  99%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########9 |  99%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########9 |  99%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########9 |  99%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########9 | 100%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########9 | 100%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########9 | 100%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########9 | 100%
#
#
# pytorch-1.12.1       | 80.6 MB   | #########9 | 100%
#
#
# pytorch-1.12.1       | 80.6 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pytorch torchvision torchaudio pytorch-cuda=11.6 -c pytorch -c nvidia
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
# ("Connection broken: ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)", ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# ("Connection broken: ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)", ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\HP\anaconda3
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda=11.6
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cuda-11.6.1                |                0           1 KB  nvidia
#     cuda-cccl-11.6.55          |                0         1.2 MB  nvidia
#     cuda-command-line-tools-11.6.2|                0           1 KB  nvidia
#     cuda-compiler-11.6.2       |                0           1 KB  nvidia
#     cuda-cudart-11.6.55        |                0         1.4 MB  nvidia
#     cuda-cudart-dev-11.6.55    |                0         672 KB  nvidia
#     cuda-cuobjdump-11.6.124    |                0         2.5 MB  nvidia
#     cuda-cupti-11.6.124        |                0        10.0 MB  nvidia
#     cuda-cuxxfilt-11.6.124     |                0         165 KB  nvidia
#     cuda-libraries-11.6.1      |                0           1 KB  nvidia
#     cuda-libraries-dev-11.6.1  |                0           1 KB  nvidia
#     cuda-memcheck-11.8.86      |                0         183 KB  nvidia
#     cuda-nsight-compute-12.0.0 |                0           1 KB  nvidia
#     cuda-nvcc-11.6.124         |                0        43.4 MB  nvidia
#     cuda-nvdisasm-12.0.76      |                0        48.0 MB  nvidia
#     cuda-nvml-dev-11.6.55      |                0          83 KB  nvidia
#     cuda-nvprof-12.0.90        |                0         1.5 MB  nvidia
#     cuda-nvprune-11.6.124      |                0         151 KB  nvidia
#     cuda-nvrtc-11.6.124        |                0        71.4 MB  nvidia
#     cuda-nvrtc-dev-11.6.124    |                0        14.3 MB  nvidia
#     cuda-nvtx-11.6.124         |                0          43 KB  nvidia
#     cuda-nvvp-12.0.90          |                0       113.6 MB  nvidia
#     cuda-runtime-11.6.1        |                0           1 KB  nvidia
#     cuda-sanitizer-api-12.0.90 |                0        12.8 MB  nvidia
#     cuda-toolkit-11.6.1        |                0           1 KB  nvidia
#     cuda-tools-11.6.1          |                0           1 KB  nvidia
#     cuda-visual-tools-11.6.1   |                0           1 KB  nvidia
#     libcublas-11.9.2.110       |                0          24 KB  nvidia
#     libcublas-dev-11.9.2.110   |                0       296.9 MB  nvidia
#     libcufft-10.7.1.112        |                0           5 KB  nvidia
#     libcufft-dev-10.7.1.112    |                0       250.1 MB  nvidia
#     libcurand-10.3.1.50        |                0           3 KB  nvidia
#     libcurand-dev-10.3.1.50    |                0        50.0 MB  nvidia
#     libcusolver-11.3.4.124     |                0          29 KB  nvidia
#     libcusolver-dev-11.3.4.124 |                0        85.6 MB  nvidia
#     libcusparse-11.7.2.124     |                0          13 KB  nvidia
#     libcusparse-dev-11.7.2.124 |                0       161.0 MB  nvidia
#     libnpp-11.6.3.124          |                0         286 KB  nvidia
#     libnpp-dev-11.6.3.124      |                0       114.6 MB  nvidia
#     libnvjpeg-11.6.2.124       |                0           4 KB  nvidia
#     libnvjpeg-dev-11.6.2.124   |                0         1.8 MB  nvidia
#     nsight-compute-2022.4.0.15 |                0       598.6 MB  nvidia
#     pytorch-1.13.1             |py3.9_cuda11.6_cudnn8_0        1.23 GB  pytorch
#     pytorch-cuda-11.6          |       h867d48c_1           3 KB  pytorch
#     pytorch-mutex-1.0          |             cuda           3 KB  pytorch
#     torchaudio-0.13.1          |       py39_cu116         4.7 MB  pytorch
#     torchvision-0.14.1         |       py39_cu116         7.5 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:        3.08 GB
#
# The following NEW packages will be INSTALLED:
#
#   cuda               nvidia/win-64::cuda-11.6.1-0
#   cuda-cccl          nvidia/win-64::cuda-cccl-11.6.55-0
#   cuda-command-line~ nvidia/win-64::cuda-command-line-tools-11.6.2-0
#   cuda-compiler      nvidia/win-64::cuda-compiler-11.6.2-0
#   cuda-cudart        nvidia/win-64::cuda-cudart-11.6.55-0
#   cuda-cudart-dev    nvidia/win-64::cuda-cudart-dev-11.6.55-0
#   cuda-cuobjdump     nvidia/win-64::cuda-cuobjdump-11.6.124-0
#   cuda-cupti         nvidia/win-64::cuda-cupti-11.6.124-0
#   cuda-cuxxfilt      nvidia/win-64::cuda-cuxxfilt-11.6.124-0
#   cuda-libraries     nvidia/win-64::cuda-libraries-11.6.1-0
#   cuda-libraries-dev nvidia/win-64::cuda-libraries-dev-11.6.1-0
#   cuda-memcheck      nvidia/win-64::cuda-memcheck-11.8.86-0
#   cuda-nsight-compu~ nvidia/win-64::cuda-nsight-compute-12.0.0-0
#   cuda-nvcc          nvidia/win-64::cuda-nvcc-11.6.124-0
#   cuda-nvdisasm      nvidia/win-64::cuda-nvdisasm-12.0.76-0
#   cuda-nvml-dev      nvidia/win-64::cuda-nvml-dev-11.6.55-0
#   cuda-nvprof        nvidia/win-64::cuda-nvprof-12.0.90-0
#   cuda-nvprune       nvidia/win-64::cuda-nvprune-11.6.124-0
#   cuda-nvrtc         nvidia/win-64::cuda-nvrtc-11.6.124-0
#   cuda-nvrtc-dev     nvidia/win-64::cuda-nvrtc-dev-11.6.124-0
#   cuda-nvtx          nvidia/win-64::cuda-nvtx-11.6.124-0
#   cuda-nvvp          nvidia/win-64::cuda-nvvp-12.0.90-0
#   cuda-runtime       nvidia/win-64::cuda-runtime-11.6.1-0
#   cuda-sanitizer-api nvidia/win-64::cuda-sanitizer-api-12.0.90-0
#   cuda-toolkit       nvidia/win-64::cuda-toolkit-11.6.1-0
#   cuda-tools         nvidia/win-64::cuda-tools-11.6.1-0
#   cuda-visual-tools  nvidia/win-64::cuda-visual-tools-11.6.1-0
#   libcublas          nvidia/win-64::libcublas-11.9.2.110-0
#   libcublas-dev      nvidia/win-64::libcublas-dev-11.9.2.110-0
#   libcufft           nvidia/win-64::libcufft-10.7.1.112-0
#   libcufft-dev       nvidia/win-64::libcufft-dev-10.7.1.112-0
#   libcurand          nvidia/win-64::libcurand-10.3.1.50-0
#   libcurand-dev      nvidia/win-64::libcurand-dev-10.3.1.50-0
#   libcusolver        nvidia/win-64::libcusolver-11.3.4.124-0
#   libcusolver-dev    nvidia/win-64::libcusolver-dev-11.3.4.124-0
#   libcusparse        nvidia/win-64::libcusparse-11.7.2.124-0
#   libcusparse-dev    nvidia/win-64::libcusparse-dev-11.7.2.124-0
#   libnpp             nvidia/win-64::libnpp-11.6.3.124-0
#   libnpp-dev         nvidia/win-64::libnpp-dev-11.6.3.124-0
#   libnvjpeg          nvidia/win-64::libnvjpeg-11.6.2.124-0
#   libnvjpeg-dev      nvidia/win-64::libnvjpeg-dev-11.6.2.124-0
#   nsight-compute     nvidia/win-64::nsight-compute-2022.4.0.15-0
#   pytorch-cuda       pytorch/noarch::pytorch-cuda-11.6-h867d48c_1
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   torchaudio         pytorch/win-64::torchaudio-0.13.1-py39_cu116
#   torchvision        pytorch/win-64::torchvision-0.14.1-py39_cu116
#
# The following packages will be UPDATED:
#
#   pytorch            pkgs/main::pytorch-1.12.1-cpu_py39h5e~ --> pytorch::pytorch-1.13.1-py3.9_cuda11.6_cudnn8_0
#
#
#
# Downloading and Extracting Packages
#
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   |            |   0%
#
#
# cuda-memcheck-11.8.8 | 183 KB    |            |   0%
#
#
#
# cuda-libraries-11.6. | 1 KB      |            |   0%
#
#
#
#
# cuda-visual-tools-11 | 1 KB      |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    |            |   0%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
#
#
#
#
#
#
# cuda-cuxxfilt-11.6.1 | 165 KB    |            |   0%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  |            |   0%
#
#
#
#
#
#
#
#
#
# cuda-nvtx-11.6.124   | 43 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-dev-11.6.3.12 | 114.6 MB  |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-command-line-to | 1 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-runtime-11.6.1  | 1 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvp-12.0.90    | 113.6 MB  |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.14.1   | 7.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-11.6.2.124 | 4 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-sanitizer-api-1 | 12.8 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# cuda-libraries-11.6. | 1 KB      | ########## | 100%
#
#
#
# cuda-libraries-11.6. | 1 KB      | ########## | 100%
#
#
# cuda-memcheck-11.8.8 | 183 KB    | 8          |   9%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
# cuda-visual-tools-11 | 1 KB      | ########## | 100%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   |            |   0%
#
#
#
#
# cuda-visual-tools-11 | 1 KB      | ########## | 100%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
# cuda-memcheck-11.8.8 | 183 KB    | ######1    |  61%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | 1          |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   |            |   0%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
# cuda-memcheck-11.8.8 | 183 KB    | ########## | 100%
#
#
# cuda-memcheck-11.8.8 | 183 KB    | ########## | 100%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | 4          |   4%
#
#
#
#
#
#
#
# cuda-cuxxfilt-11.6.1 | 165 KB    | 9          |  10%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | #1         |  11%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
#
#
# cuda-cuxxfilt-11.6.1 | 165 KB    | ########## | 100%
#
#
#
#
#
#
#
# cuda-cuxxfilt-11.6.1 | 165 KB    | ########## | 100%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | #5         |  15%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   |            |   1%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | ##1        |  22%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   |            |   1%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | ##6        |  27%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  |            |   0%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | ###1       |  32%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 1          |   2%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | ###8       |  38%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  |            |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  |            |   1%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | ####3      |  43%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 2          |   2%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  |            |   1%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | ####7      |  47%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  |            |   1%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 2          |   3%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | #####1     |  52%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  |            |   1%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 2          |   3%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | #####4     |  55%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 3          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 1          |   1%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | #####9     |  60%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 3          |   4%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 1          |   1%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | ######5    |  66%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 3          |   4%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 1          |   1%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | #######2   |  72%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 4          |   4%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 1          |   1%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | #######8   |  78%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 4          |   5%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 1          |   1%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | ########4  |  84%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 4          |   5%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   1%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | ########9  |  90%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 1          |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 5          |   5%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 5          |   6%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   1%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 1          |   2%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | ########## | 100%
#
#
#
#
#
# cuda-nvprof-12.0.90  | 1.5 MB    | ########## | 100%
# nsight-compute-2022. | 598.6 MB  |            |   0%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 7          |   7%
#
#
#
#
#
#
#
#
#
# cuda-nvtx-11.6.124   | 43 KB     | ###7       |  37%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   1%
#
#
#
#
#
#
#
#
#
# cuda-nvtx-11.6.124   | 43 KB     | #######4   |  75%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 7          |   8%
#
#
#
#
#
#
#
#
#
# cuda-nvtx-11.6.124   | 43 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 2          |   2%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   |            |   0%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 8          |   8%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 2          |   2%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 8          |   9%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   |            |   0%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 2          |   2%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 9          |  10%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   |            |   0%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   1%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | 9          |  10%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   |            |   0%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 2          |   2%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #          |  11%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 2          |   2%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   |            |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #1         |  11%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 2          |   3%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   1%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   |            |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 2          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #1         |  11%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 1          |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 2          |   3%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #2         |  12%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 1          |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  |            |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 2          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #3         |  13%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 1          |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #3         |  14%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #4         |  14%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #4         |  15%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 3          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #5         |  16%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 1          |   2%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 3          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #6         |  17%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 1          |   2%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #8         |  19%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 2          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 3          |   3%
# nsight-compute-2022. | 598.6 MB  |            |   1%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 2          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #9         |  20%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 3          |   4%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 3          |   4%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 2          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##         |  20%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 3          |   4%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##1        |  22%
# nsight-compute-2022. | 598.6 MB  |            |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 2          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##2        |  22%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 3          |   4%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 2          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##3        |  23%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 4          |   4%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##3        |  24%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 4          |   4%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 2          |   3%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##4        |  25%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 2          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 4          |   4%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##5        |  25%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 3          |   3%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   2%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 3          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##5        |  26%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   2%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 4          |   4%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##6        |  26%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 3          |   3%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 1          |   2%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 4          |   4%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##7        |  28%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 3          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 4          |   5%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 3          |   4%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##8        |  28%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 4          |   5%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##9        |  29%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 3          |   4%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   2%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ##9        |  30%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 4          |   5%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ###        |  30%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   2%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 4          |   5%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ###1       |  31%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ###1       |  32%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 4          |   5%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 3          |   4%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 5          |   5%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 3          |   4%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ###2       |  33%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 5          |   5%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ###3       |  34%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ###4       |  34%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 4          |   4%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ###5       |  35%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 5          |   5%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 4          |   4%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ###5       |  36%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 5          |   5%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 4          |   4%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   2%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ###6       |  37%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 5          |   5%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   2%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 5          |   6%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   3%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 5          |   6%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ###7       |  37%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 5          |   6%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ###7       |  38%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   3%
# nsight-compute-2022. | 598.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 4          |   4%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 5          |   6%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ###9       |  39%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   3%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 5          |   6%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ####2      |  42%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 4          |   5%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   6%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 4          |   5%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   6%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   3%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ####3      |  43%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   6%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   3%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   6%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 4          |   5%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ####4      |  44%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ####4      |  45%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   5%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ####5      |  46%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   5%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   7%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   5%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ####6      |  46%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   5%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   7%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ####7      |  47%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   3%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   7%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   7%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   3%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   5%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   7%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   5%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ####9      |  49%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   4%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 6          |   7%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   5%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   4%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   7%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   5%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   4%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   7%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   5%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   4%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   7%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ####9      |  50%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   4%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   7%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   7%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   4%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   7%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   7%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #####      |  50%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   7%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #####1     |  52%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   8%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   4%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   4%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   4%
# nsight-compute-2022. | 598.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #####2     |  52%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   4%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   4%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #####2     |  53%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   8%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #####3     |  54%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 7          |   8%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 8          |   8%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   4%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 8          |   8%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   4%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 8          |   8%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   4%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 8          |   8%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   5%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 5          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 8          |   8%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   5%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 8          |   8%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   5%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   6%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #####4     |  54%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #####5     |  56%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 8          |   9%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   5%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 8          |   9%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   5%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 8          |   9%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 4          |   5%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   5%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 8          |   9%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #####6     |  56%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 9          |   9%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   5%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #####8     |  58%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 9          |   9%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #####8     |  59%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   5%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 9          |   9%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #####9     |  59%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   5%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 9          |   9%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   5%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #####9     |  60%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 9          |  10%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######     |  61%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   5%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   7%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   5%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 9          |  10%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 9          |  10%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 9          |  10%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   6%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 9          |  10%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   6%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######2    |  62%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######2    |  63%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 2          |   2%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######3    |  64%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  10%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######4    |  64%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######4    |  65%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   6%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######5    |  65%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  10%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   7%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   6%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######6    |  66%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  10%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 6          |   7%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 5          |   6%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######6    |  67%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  10%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######7    |  67%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 7          |   7%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  10%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 7          |   7%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######7    |  68%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  11%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 7          |   7%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  11%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 7          |   7%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   6%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  11%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 7          |   7%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  11%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######8    |  68%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 7          |   7%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  11%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   6%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 7          |   7%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  11%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | ######8    |  69%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  11%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 7          |   8%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######    |  70%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #          |  11%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   6%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 7          |   8%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######1   |  72%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   6%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  11%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 7          |   8%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   6%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######2   |  72%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  11%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 7          |   8%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   7%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  11%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######2   |  73%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 7          |   8%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  11%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  11%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######3   |  73%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   7%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  11%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######3   |  74%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 8          |   8%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 8          |   8%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  12%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######4   |  75%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 8          |   8%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   7%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  12%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######5   |  75%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   7%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 8          |   8%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######5   |  76%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######6   |  76%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  12%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   7%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  12%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######7   |  78%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 8          |   8%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   7%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #1         |  12%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 6          |   7%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #2         |  12%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 8          |   9%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #2         |  12%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 7          |   7%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######8   |  79%
# nsight-compute-2022. | 598.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 8          |   9%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 7          |   7%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #2         |  12%
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.1 | 50.0 MB   | 8          |   9%
#
# cuda-nvrtc-dev-11.6. | 14.3 MB   | #######9   |  80%
#
#
#
#
#
#
# libcublas-dev-11.9.2 | 296.9 MB  | 7          |   7%
#
#
#
#
#
#
#
#
# libcusparse-dev-11.7 | 161.0 MB  | #2         |  12%
# ...
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  35%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###5       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  36%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###6       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###7       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###7       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###7       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###7       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###7       |  37%
# nsight-compute-2022. | 598.6 MB  | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###7       |  37%
# nsight-compute-2022. | 598.6 MB  | ########## | 100%
# nsight-compute-2022. | 598.6 MB  | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.23 GB   | ###7       |  37%

# %%
conda install torchvision
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\HP\anaconda3
#
#   added / updated specs:
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     torchvision-0.13.1         |cpu_py39h378ed51_0         6.1 MB
#     ------------------------------------------------------------
#                                            Total:         6.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   torchvision        pkgs/main/win-64::torchvision-0.13.1-cpu_py39h378ed51_0
#
#
#
# Downloading and Extracting Packages
#
# torchvision-0.13.1   | 6.1 MB    |            |   0%
# torchvision-0.13.1   | 6.1 MB    |            |   0%
# torchvision-0.13.1   | 6.1 MB    | 1          |   2%
# torchvision-0.13.1   | 6.1 MB    | 3          |   3%
# torchvision-0.13.1   | 6.1 MB    | 3          |   4%
# torchvision-0.13.1   | 6.1 MB    | 4          |   4%
# torchvision-0.13.1   | 6.1 MB    | 5          |   6%
# torchvision-0.13.1   | 6.1 MB    | 6          |   7%
# torchvision-0.13.1   | 6.1 MB    | 7          |   7%
# torchvision-0.13.1   | 6.1 MB    | 8          |   8%
# torchvision-0.13.1   | 6.1 MB    | 9          |   9%
# torchvision-0.13.1   | 6.1 MB    | 9          |  10%
# torchvision-0.13.1   | 6.1 MB    | #          |  10%
# torchvision-0.13.1   | 6.1 MB    | #          |  11%
# torchvision-0.13.1   | 6.1 MB    | #1         |  12%
# torchvision-0.13.1   | 6.1 MB    | #2         |  13%
# torchvision-0.13.1   | 6.1 MB    | #3         |  13%
# torchvision-0.13.1   | 6.1 MB    | #3         |  14%
# torchvision-0.13.1   | 6.1 MB    | #5         |  15%
# torchvision-0.13.1   | 6.1 MB    | #5         |  16%
# torchvision-0.13.1   | 6.1 MB    | #6         |  17%
# torchvision-0.13.1   | 6.1 MB    | #7         |  17%
# torchvision-0.13.1   | 6.1 MB    | #8         |  18%
# torchvision-0.13.1   | 6.1 MB    | #9         |  19%
# torchvision-0.13.1   | 6.1 MB    | #9         |  20%
# torchvision-0.13.1   | 6.1 MB    | ##         |  21%
# torchvision-0.13.1   | 6.1 MB    | ##1        |  22%
# torchvision-0.13.1   | 6.1 MB    | ##2        |  23%
# torchvision-0.13.1   | 6.1 MB    | ##3        |  24%
# torchvision-0.13.1   | 6.1 MB    | ##4        |  25%
# torchvision-0.13.1   | 6.1 MB    | ##5        |  25%
# torchvision-0.13.1   | 6.1 MB    | ##6        |  26%
# torchvision-0.13.1   | 6.1 MB    | ##7        |  27%
# torchvision-0.13.1   | 6.1 MB    | ##8        |  28%
# torchvision-0.13.1   | 6.1 MB    | ##9        |  29%
# torchvision-0.13.1   | 6.1 MB    | ###        |  30%
# torchvision-0.13.1   | 6.1 MB    | ###1       |  32%
# torchvision-0.13.1   | 6.1 MB    | ###2       |  33%
# torchvision-0.13.1   | 6.1 MB    | ###4       |  35%
# torchvision-0.13.1   | 6.1 MB    | ###6       |  37%
# torchvision-0.13.1   | 6.1 MB    | ###7       |  38%
# torchvision-0.13.1   | 6.1 MB    | ###9       |  39%
# torchvision-0.13.1   | 6.1 MB    | ####       |  40%
# torchvision-0.13.1   | 6.1 MB    | ####1      |  42%
# torchvision-0.13.1   | 6.1 MB    | ####3      |  43%
# torchvision-0.13.1   | 6.1 MB    | ####4      |  44%
# torchvision-0.13.1   | 6.1 MB    | ####5      |  46%
# torchvision-0.13.1   | 6.1 MB    | ####6      |  47%
# torchvision-0.13.1   | 6.1 MB    | ####8      |  49%
# torchvision-0.13.1   | 6.1 MB    | #####      |  51%
# torchvision-0.13.1   | 6.1 MB    | #####2     |  53%
# torchvision-0.13.1   | 6.1 MB    | #####3     |  54%
# torchvision-0.13.1   | 6.1 MB    | #####5     |  55%
# torchvision-0.13.1   | 6.1 MB    | #####6     |  57%
# torchvision-0.13.1   | 6.1 MB    | #####7     |  58%
# torchvision-0.13.1   | 6.1 MB    | #####9     |  59%
# torchvision-0.13.1   | 6.1 MB    | ######     |  61%
# torchvision-0.13.1   | 6.1 MB    | ######1    |  62%
# torchvision-0.13.1   | 6.1 MB    | ######3    |  63%
# torchvision-0.13.1   | 6.1 MB    | ######4    |  65%
# torchvision-0.13.1   | 6.1 MB    | ######5    |  66%
# torchvision-0.13.1   | 6.1 MB    | ######7    |  67%
# torchvision-0.13.1   | 6.1 MB    | ######8    |  69%
# torchvision-0.13.1   | 6.1 MB    | #######    |  71%
# torchvision-0.13.1   | 6.1 MB    | #######2   |  72%
# torchvision-0.13.1   | 6.1 MB    | #######4   |  74%
# torchvision-0.13.1   | 6.1 MB    | #######5   |  76%
# torchvision-0.13.1   | 6.1 MB    | #######6   |  77%
# torchvision-0.13.1   | 6.1 MB    | #######7   |  78%
# torchvision-0.13.1   | 6.1 MB    | ########   |  81%
# torchvision-0.13.1   | 6.1 MB    | ########2  |  83%
# torchvision-0.13.1   | 6.1 MB    | ########5  |  86%
# torchvision-0.13.1   | 6.1 MB    | ########7  |  87%
# torchvision-0.13.1   | 6.1 MB    | #########  |  91%
# torchvision-0.13.1   | 6.1 MB    | #########2 |  93%
# torchvision-0.13.1   | 6.1 MB    | #########4 |  95%
# torchvision-0.13.1   | 6.1 MB    | #########6 |  97%
# torchvision-0.13.1   | 6.1 MB    | #########8 |  98%
# torchvision-0.13.1   | 6.1 MB    | ########## | 100%
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename C:\Users\HP\anaconda3\pkgs\libcufft-dev-10.7.1.112-0.tar.bz2.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename C:\Users\HP\anaconda3\pkgs\pytorch-1.13.1-py3.9_cuda11.6_cudnn8_0.tar.bz2.  Please remove this file manually (you may need to reboot to free file handles)

# %%
import torch
print(torch.__version__)
# Out:
# 1.13.1+cpu

# %%
import torch 
import torchvision

# %%
torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=None)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data\MNIST\raw\train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./data\MNIST\raw\train-images-idx3-ubyte.gz to ./data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data\MNIST\raw\train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./data\MNIST\raw\train-labels-idx1-ubyte.gz to ./data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data\MNIST\raw\t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data\MNIST\raw\t10k-images-idx3-ubyte.gz to ./data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data\MNIST\raw\t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./data\MNIST\raw\t10k-labels-idx1-ubyte.gz to ./data\MNIST\raw
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test

# %%
from torchvision import datasets as dts
from torchvision.transforms import ToTensor

# %%
traindt = dts.MNIST(
    root = 'data',
    train = True,                         
    transform = ToTensor(), 
    download = True,            
)
testdt = dts.MNIST(
    root = 'data', 
    train = False, 
    transform = ToTensor()
)

# %%
import torch as trch
import torchvision.datasets as dts
import torchvision.transforms as trnsfrms
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
transf = trnsfrms.Compose([trnsfrms.ToTensor(), trnsfrms.Normalize((0.7,), (0.7,)),])

mnisttrainset = dts.MNIST(root='./data', train=True, download=True, transform=trnsfrms)
trainldr = trch.utils.data.DataLoader(mnisttrainset, batch_size=10, shuffle=True)

# %%
mnist_testset = dts.MNIST(root='./data', train=False, download=True, transform=trnsfrms)
testldr = trch.utils.data.DataLoader(mnist_testset, batch_size=10, shuffle=True)
trnsform = trnsfrms.Compose([trnsfrms.ToTensor(), trnsfrms.Normalize((0.7,), (0.7,)),])

# %%
class classicationmodel(nn.Module):
    
    def __init__(self):
        super( classicationmodel,self).__init__()
        self.linear1 = nn.Linear(28*28, 100) 
        self.linear2 = nn.Linear(100, 50) 
        self.final = nn.Linear(50, 10)
        self.relu = nn.ReLU()
        
        
    def forward(self, image):
        a = image.view(-1, 28*28)
        a = self.relu(self.linear1(a))
        a = self.relu(self.linear2(a))
        a = self.final(a)
        return a

cmodel = classicationmodel()
print(cmodel)
# Out:
# classicationmodel(
#   (linear1): Linear(in_features=784, out_features=100, bias=True)
#   (linear2): Linear(in_features=100, out_features=50, bias=True)
#   (final): Linear(in_features=50, out_features=10, bias=True)
#   (relu): ReLU()
# )

# %% [markdown]
# # get the CNN data

# %%
import torch.nn as nn
class cnn(nn.Module):
    def __init__(self):
        super(cnn, self).__init__()
        self.conv = nn.Sequential(         
            nn.Conv2d(
                in_channels=3,              
                out_channels=18,            
                kernel_size=7,              
                stride=3,                   
                padding=4,                  
            ),                              
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=4),    
        )
        self.conv1 = nn.Sequential(         
            nn.Conv2d(18, 34, 7, 3, 4),     
            nn.ReLU(),                      
            nn.MaxPool2d(2),                
        )
        
        self.out = nn.Linear(34 * 9 * 9, 12)
    def forward(self, a):
        a = self.conv1(a)
        a = self.conv2(a)
        a = a.view(a.size(0), -1)       
        outp = self.out(a)
        return outp, a 
CNN = cnn()
print(CNN)
# Out:
# cnn(
#   (conv): Sequential(
#     (0): Conv2d(3, 18, kernel_size=(7, 7), stride=(3, 3), padding=(4, 4))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv1): Sequential(
#     (0): Conv2d(18, 34, kernel_size=(7, 7), stride=(3, 3), padding=(4, 4))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (out): Linear(in_features=2754, out_features=12, bias=True)
# )

# %% [markdown]
# # train the model with training data

# %%
inpsiz = 784 
hidensiz = 500 
numclases = 10
numepchs = 4
bachsiz = 100
l_r = 0.001 

trainds = torchvision.datasets.MNIST(root='./data', 
                                          train=True, 
                                          transform=trnsfrms.ToTensor(),  
                                          download=True)
testds = torchvision.datasets.MNIST(root='./data', 
                                           train=False, 
                                           transform=trnsfrms.ToTensor()) 

trainldr = torch.utils.data.DataLoader(dataset=trainds, 
                                           batch_size=bachsiz, 
                                           shuffle=True)
testldr = torch.utils.data.DataLoader(dataset=testds, 
                                           batch_size=bachsiz, 
                                           shuffle=False)

class neural_network(nn.Module):
    def __init__(self, inpsiz, hidensiz, numclases):
         super(neural_network, self).__init__()
         self.inputsiz = inpsiz
         self.l1 = nn.Linear(inpsiz, hidensiz) 
         self.relu = nn.ReLU()
         self.l2 = nn.Linear(hidensiz, numclases) 
    def forward(self, y):
         outp = self.l1(y)
         outp = self.relu(outp)
         outp = self.l2(outp)

         return outp
modl = neural_network(inpsiz, hidensiz, numclases)

criter = nn.CrossEntropyLoss()
optim = torch.optim.Adam(modl.parameters(), lr=l_r)
nttlstps = len(trainldr)
for epoch in range(numepchs):
    for x, (imgs, lbls) in enumerate(trainldr): 
         imgs = imgs.reshape(-1, 28*28)
         labls = lbls

         outp = modl(imgs)
         losses = criter(outp, lbls)

         optim.zero_grad()
         losses.backward()
         optim.step() 
    if (x+1) % 100 == 0:
             print (f'Epochs [{epoch+1}/{numepchs}], Step[{x+1}/{nttlstps}], Losses: {losses.item():.4f}')
# Out:
# Epochs [1/4], Step[600/600], Losses: 0.0682
# Epochs [2/4], Step[600/600], Losses: 0.0892
# Epochs [3/4], Step[600/600], Losses: 0.0746
# Epochs [4/4], Step[600/600], Losses: 0.0164

# %%
from torch.utils.data import DataLoader 
ldrs = {
    'train' : torch.utils.data.DataLoader(trainds, 
                                          batch_size=80, 
                                          shuffle=True, 
                                          num_workers=1),
    
    'test'  : torch.utils.data.DataLoader(testds, 
                                          batch_size=80, 
                                          shuffle=True, 
                                          num_workers=1),
}
import torch.nn as nn
class cnn(nn.Module):
    def __init__(self):
        super(cnn, self).__init__()
        self.conv = nn.Sequential(         
            nn.Conv2d(
                in_channels=1,              
                out_channels=16,            
                kernel_size=5,              
                stride=1,                   
                padding=2,                  
            ),                              
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2),    
        )
        self.conv1 = nn.Sequential(         
            nn.Conv2d(16, 32, 5, 1, 2),     
            nn.ReLU(),                      
            nn.MaxPool2d(2),                
        )
        self.out = nn.Linear(32 * 7 * 7, 10)
    def forward(self, y):
        y = self.conv(y)
        y = self.conv1(y)
        y = y.view(y.size(0), -1)       
        outp = self.out(y)
        return outp, y   
Cnn = cnn()
lossfunct = nn.CrossEntropyLoss()   
from torch import optim
optim = optim.Adam(Cnn.parameters(), lr = 0.01)   
from torch.autograd import Variable as var
numepch = 3
def train(numepchs, Cnn, ldrs):
    
    Cnn.train()
        
    # Train the model
    ttlstp = len(ldrs['train'])
        
    for epoch in range(numepchs):
        for a, (imgs, lbls) in enumerate(ldrs['train']):
            ax = var(imgs)   
            ay = var(lbls)   
            outp = Cnn(ax)[0]               
            losses = lossfunct(outp, ay)
            
              
            optim.zero_grad()           
            losses.backward()    
                      
            optim.step()                
            
            if (a+1) % 100 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                       .format(epoch + 1, numepchs, i + 1, ttlstp, losses.item()))

def test():
    # Test the model
    Cnn.eval()
    with torch.no_grad():
        corct = 0
        ttl = 0
        for imgs, lbls in ldrs['test']:
            testoutp, lstlayr = Cnn(imgs)
            predicy = torch.max(testoutp, 1)[1].data.squeeze()
            accu = (predicy == lbls).sum().item() / float(lbls.size(0))
            pass
            print(' Accuracy of the model  %.2f' % accu)
test()
# Out:
#  Accuracy of the model  0.14
#  Accuracy of the model  0.14
#  Accuracy of the model  0.07
#  Accuracy of the model  0.12
#  Accuracy of the model  0.11
#  Accuracy of the model  0.17
#  Accuracy of the model  0.10
#  Accuracy of the model  0.16
#  Accuracy of the model  0.07
#  Accuracy of the model  0.15
#  Accuracy of the model  0.09
#  Accuracy of the model  0.14
#  Accuracy of the model  0.10
#  Accuracy of the model  0.11
#  Accuracy of the model  0.15
#  Accuracy of the model  0.10
#  Accuracy of the model  0.09
#  Accuracy of the model  0.10
#  Accuracy of the model  0.15
#  Accuracy of the model  0.06
#  Accuracy of the model  0.12
#  Accuracy of the model  0.19
#  Accuracy of the model  0.10
#  Accuracy of the model  0.06
#  Accuracy of the model  0.14
#  Accuracy of the model  0.06
#  Accuracy of the model  0.09
#  Accuracy of the model  0.11
#  Accuracy of the model  0.06
#  Accuracy of the model  0.12
#  Accuracy of the model  0.09
#  Accuracy of the model  0.15
#  Accuracy of the model  0.09
#  Accuracy of the model  0.12
#  Accuracy of the model  0.11
#  Accuracy of the model  0.10
#  Accuracy of the model  0.12
#  Accuracy of the model  0.12
#  Accuracy of the model  0.15
#  Accuracy of the model  0.07
#  Accuracy of the model  0.11
#  Accuracy of the model  0.09
#  Accuracy of the model  0.11
#  Accuracy of the model  0.09
#  Accuracy of the model  0.12
#  Accuracy of the model  0.11
#  Accuracy of the model  0.11
#  Accuracy of the model  0.11
#  Accuracy of the model  0.09
#  Accuracy of the model  0.12
#  Accuracy of the model  0.09
#  Accuracy of the model  0.09
#  Accuracy of the model  0.17
#  Accuracy of the model  0.10
#  Accuracy of the model  0.12
#  Accuracy of the model  0.17
#  Accuracy of the model  0.14
#  Accuracy of the model  0.07
#  Accuracy of the model  0.09
#  Accuracy of the model  0.09
#  Accuracy of the model  0.14
#  Accuracy of the model  0.21
#  Accuracy of the model  0.10
#  Accuracy of the model  0.07
#  Accuracy of the model  0.10
#  Accuracy of the model  0.10
#  Accuracy of the model  0.17
#  Accuracy of the model  0.15
#  Accuracy of the model  0.14
#  Accuracy of the model  0.06
#  Accuracy of the model  0.11
#  Accuracy of the model  0.10
#  Accuracy of the model  0.09
#  Accuracy of the model  0.09
#  Accuracy of the model  0.09
#  Accuracy of the model  0.12
#  Accuracy of the model  0.11
#  Accuracy of the model  0.16
#  Accuracy of the model  0.12
#  Accuracy of the model  0.06
#  Accuracy of the model  0.14
#  Accuracy of the model  0.06
#  Accuracy of the model  0.14
#  Accuracy of the model  0.12
#  Accuracy of the model  0.03
#  Accuracy of the model  0.06
#  Accuracy of the model  0.14
#  Accuracy of the model  0.06
#  Accuracy of the model  0.09
#  Accuracy of the model  0.14
#  Accuracy of the model  0.07
#  Accuracy of the model  0.10
#  Accuracy of the model  0.06
#  Accuracy of the model  0.15
#  Accuracy of the model  0.16
#  Accuracy of the model  0.19
#  Accuracy of the model  0.17
#  Accuracy of the model  0.16
#  Accuracy of the model  0.07
#  Accuracy of the model  0.11
#  Accuracy of the model  0.17
#  Accuracy of the model  0.11
#  Accuracy of the model  0.11
#  Accuracy of the model  0.16
#  Accuracy of the model  0.07
#  Accuracy of the model  0.15
#  Accuracy of the model  0.12
#  Accuracy of the model  0.14
#  Accuracy of the model  0.06
#  Accuracy of the model  0.09
#  Accuracy of the model  0.15
#  Accuracy of the model  0.10
#  Accuracy of the model  0.19
#  Accuracy of the model  0.11
#  Accuracy of the model  0.09
#  Accuracy of the model  0.10
#  Accuracy of the model  0.12
#  Accuracy of the model  0.07
#  Accuracy of the model  0.09
#  Accuracy of the model  0.09
#  Accuracy of the model  0.11
#  Accuracy of the model  0.07
#  Accuracy of the model  0.14
#  Accuracy of the model  0.11
#  Accuracy of the model  0.09
